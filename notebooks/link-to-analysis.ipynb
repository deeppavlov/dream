# %%
import json
import pandas as pd
from collections import defaultdict
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %%
def get_link(u, link_tos):
    for k, v in link_tos.items():
        for link in v:
            if link.lower() in u['text'].lower():
                return k
    return None


def get_links_usage(data, link_tos):
    total_links = defaultdict(int)
    success_links = defaultdict(int)
    total_links_ratings = defaultdict(list)
    success_links_ratings = defaultdict(list)
    for dialog in data:
        rating = dialog['rating']
        utts = dialog['utterances']
        total_links_rating = {}
        success_links_rating = {}
        for i, u in enumerate(utts):
            if u.get('active_skill'):
                link = get_link(u, link_tos)
                if link:
                    total_links[link] += 1
                    if total_links_rating.get(link) is None:
                        total_links_rating[link] = rating
                    if i < len(utts) - 2:
                        if utts[i + 2].get('active_skill') == link:
                            success_links[link] += 1
                            if success_links_rating.get(link) is None:
                                success_links_rating[link] = rating
        for k in total_links_rating.keys():
            total_links_ratings[k].append(total_links_rating[k])
        for k in success_links_rating.keys():
            success_links_ratings[k].append(success_links_rating[k])
            
    percentage_links = {}
    total_links_percentage = {}
    total_links_count = sum([total_links[k] for k in total_links.keys()])
    for k in total_links.keys():
        percentage_links[k] = success_links[k] / total_links[k]
        total_links_ratings[k] = sum(total_links_ratings[k]) / len(total_links_ratings[k])
        success_links_ratings[k] = sum(success_links_ratings[k]) / len(success_links_ratings[k])
        total_links_percentage[k] = total_links[k] / total_links_count
    keys = list(sorted(total_links.keys()))
    def get_v(l):
        return [l[k] for k in keys]
        
    return {'total_links': get_v(total_links), 'success_links': get_v(success_links), 'percentage_links': get_v(percentage_links), 
            'total_links_ratings': get_v(total_links_ratings), 'success_links_ratings': get_v(success_links_ratings),
            'keys': keys, 'total_links_percentage': get_v(total_links_percentage)}

# %%
link_931 = {'book_skill': {"What is the recent book you've read?"},
 'coronavirus_skill': {'Are you staying at home and working remotely to avoid coronavirus?',
  'Are you staying at home to avoid coronavirus?'},
 'emotion_skill': {'How do you feel?'},
 'meta_script_skill': {"If you would like to talk about something else just say, 'lets talk about something else'.",
  'What would you like to talk about?'},
 'movie_skill': {'Have you seen any good movies lately?',
  'Is there a movie you could watch over and over again?',
  'What is the best movie you have ever seen?',
  'What is the funniest movie you have ever seen?',
  'What is the most romantic movie you have ever seen?',
  "What is the recent movie you've watched?",
  'What is the scariest movie you have ever seen?',
  'What is your all-time favorite movie?',
  'What is your favorite TV-series?',
  'What is your favorite TV-show?',
  'What is your favorite movie?',
  'What was the last TV-series you watched?',
  'What was the last movie you watched?'},
 'news_api_skill': {'Oh! Breaking news! Would you like to hear it?'},
 'personal_info_skill': {'What is your name?', 'Where are you from?'},
 'short_story_skill': {"If you would like to hear a short story just say, 'tell me a short story'."},
 'weather_skill': {'Would you like to know the weather?', 'Would you like to know the weather there?'}}

link_942 = {'book_skill': {"What is the last book you've read?"},
 'coronavirus_skill': {'Are you staying at home and working remotely to avoid coronavirus?',
  'Are you staying at home to avoid coronavirus?'},
 'emotion_skill': {'How do you feel?'},
 'game_cooperative_skill': {'If you want to talk about games just say, "let\'s talk about games"'},
 'meta_script_skill': {'Do you have any hidden talents or surprising hobbies?',
  'Do you play any sports?',
  'How were your weekends?',
  "If you would like to talk about something else just say, 'lets talk about something else'.",
  'What do you get up to in your free time?',
  'What do you like to do?',
  'What do you usually do on the weekends?',
  'What sort of hobbies do you have?',
  'What would you like to talk about?'},
 'movie_skill': {'Is there a movie you could watch over and over again?',
  'What is the best movie you have ever seen?',
  'What is the funniest movie you have ever seen?',
  'What is the most romantic movie you have ever seen?',
  "What is the recent movie you've watched?",
  'What is the scariest movie you have ever seen?',
  'What is your all-time favorite movie?',
  'What is your favorite TV-series?'},
 'news_api_skill': {'Oh! Breaking news! Would you like to hear it?'},
 'personal_info_skill': {'What is your name?', 'Where are you from?'},
 'short_story_skill': {"If you would like to hear a short story just say, 'tell me a short story'."},
 'weather_skill': {'Would you like to know the weather?', 'Would you like to know the weather there?'}}

link_9402 = {'book_skill': {"What is the last book you've read?"},
 'coronavirus_skill': {'Are you staying at home and working remotely to avoid coronavirus?',
  'Are you staying at home to avoid coronavirus?'},
 'emotion_skill': {'How do you feel?'},
 'game_cooperative_skill': {'If you want to talk about games just say, "let\'s talk about games"'},
 'meta_script_skill': {"If you would like to talk about something else just say, 'lets talk about something else'.",
  'What would you like to talk about?'},
 'movie_skill': {'Is there a movie you could watch over and over again?',
  'What is the best movie you have ever seen?',
  'What is the funniest movie you have ever seen?',
  'What is the most romantic movie you have ever seen?',
  "What is the recent movie you've watched?",
  'What is the scariest movie you have ever seen?',
  'What is your all-time favorite movie?',
  'What is your favorite TV-series?'},
 'news_api_skill': {'Oh! Breaking news! Would you like to hear it?'},
 'personal_info_skill': {'What is your name?', 'Where are you from?'},
 'short_story_skill': {"If you would like to hear a short story just say, 'tell me a short story'."},
 'weather_skill': {'Would you like to know the weather?', 'Would you like to know the weather there?'}}

link_950 = {'book_skill': {"What is the last book you've read?"},
 'coronavirus_skill': {'Are you staying at home and working remotely to avoid coronavirus?',
  'Are you staying at home to avoid coronavirus?'},
 'emotion_skill': {'How do you feel?'},
 'game_cooperative_skill': {'If you want to talk about games just say, "let\'s talk about games"'},
 'meta_script_skill': {'Do you have any hidden talents or surprising hobbies?',
  'Do you play any sports?',
  'How were your weekends?',
  "If you would like to talk about something else just say, 'lets talk about something else'.",
  'What do you get up to in your free time?',
  'What do you like to do?',
  'What do you usually do on the weekends?',
  'What sort of hobbies do you have?',
  'What would you like to talk about?'},
 'movie_skill': {'Is there a movie you could watch over and over again?',
  'What is the best movie you have ever seen?',
  'What is the funniest movie you have ever seen?',
  'What is the most romantic movie you have ever seen?',
  "What is the recent movie you've watched?",
  'What is the scariest movie you have ever seen?',
  'What is your all-time favorite movie?',
  'What is your favorite TV-series?'},
 'news_api_skill': {'Oh! Breaking news! Would you like to hear it?'},
 'personal_info_skill': {'What is your name?', 'Where are you from?'},
 'short_story_skill': {'Do you mind if I tell you a story?',
  "If you would like to hear a short story just say, 'tell me a short story'.",
  'Speaking of me, this week I’ve had a great time chatting with different people.         I even made some new friends. One told me a cool story, do you want to hear it?'},
 'weather_skill': {'Would you like to know the weather?', 'Would you like to know the weather there?'}}

link_960 = {'book_skill': {"What is the last book you've read?"},
 'coronavirus_skill': {'Are you staying at home and working remotely to avoid coronavirus?',
  'Are you staying at home to avoid coronavirus?'},
 'emotion_skill': {'How do you feel?'},
 'game_cooperative_skill': {'If you want to talk about games just say, "let\'s talk about games"'},
 'meta_script_skill': {'Do you have any hidden talents?',
  'Do you play any sports?',
  'How were your weekends?',
  "If you would like to talk about something else just say, 'lets talk about something else'.",
  'What do you like to do?',
  'What do you usually do on the weekends?'},
 'movie_skill': {'Is there a movie you could watch over and over again?',
  'What is the best movie you have ever seen?',
  'What is the funniest movie you have ever seen?',
  'What is the most romantic movie you have ever seen?',
  "What is the recent movie you've watched?",
  'What is the scariest movie you have ever seen?',
  'What is your all-time favorite movie?',
  'What is your favorite TV-series?'},
 'news_api_skill': {'Oh! Breaking news! Would you like to hear it?'},
 'personal_info_skill': {'What is your name?', 'Where are you from?'},
 'short_story_skill': {'Do you mind if I tell you a story?',
  "If you would like to hear a short story just say, 'tell me a short story'.",
  'Speaking of me, this week I’ve had a great time chatting with different people.         I even made some new friends. One told me a cool story, do you want to hear it?'},
 'weather_skill': {'Would you like to know the weather?', 'Would you like to know the weather there?'}}

link_961 = {'book_skill': {"What is the last book you've read?"},
 'coronavirus_skill': {'Are you staying at home and working remotely to avoid coronavirus?',
  'Are you staying at home to avoid coronavirus?'},
 'emotion_skill': {'How do you feel?'},
 'game_cooperative_skill': {'If you want to talk about games just say, "let\'s talk about games"'},
 'meta_script_skill': {'Do you have any hidden talents?',
  'Do you play any sports?',
  'How were your weekends?',
  "If you would like to talk about something else just say, 'lets talk about something else'.",
  'What do you like to do?',
  'What do you usually do on the weekends?'},
 'movie_skill': {'Is there a movie you could watch over and over again?',
  'What is the best movie you have ever seen?',
  'What is the funniest movie you have ever seen?',
  'What is the most romantic movie you have ever seen?',
  "What is the recent movie you've watched?",
  'What is the scariest movie you have ever seen?',
  'What is your all-time favorite movie?',
  'What is your favorite TV-series?'},
 'news_api_skill': {'Oh! Breaking news! Would you like to hear it?'},
 'personal_info_skill': {'What is your name?', 'Where are you from?'},
 'short_story_skill': {"If you would like to hear a short story just say, 'tell me a short story'."},
 'weather_skill': {'Would you like to know the weather?', 'Would you like to know the weather there?'}}

# %%
with open('/tmp/alexaprize-export-2.json', 'r') as f:
    data931 = json.load(f)

with open('/tmp/alexaprize-export-3.json', 'r') as f:
    data950 = json.load(f)

with open('/tmp/alexaprize-export-4.json', 'r') as f:
    data942 = json.load(f)

with open('/home/idris/Documents/alexaprize-version-dialogs/alexaprize-export-v9.4.0.2', 'r') as f:
    data9402 = json.load(f)

with open('/home/idris/Documents/alexaprize-version-dialogs/alexaprize-export-v9.6.0.json', 'r') as f:
    data960 = json.load(f)    

with open('/home/idris/Documents/alexaprize-version-dialogs/alexaprize-export-v9.6.1.json', 'r') as f:
    data961 = json.load(f)

# %%
links_usage = {'v9.5.0': get_links_usage(data950, link_950), 
               'v9.4.2': get_links_usage(data942, link_942), 
               'v9.3.1': get_links_usage(data931, link_931), 
               'v9.4.0.2': get_links_usage(data9402, link_9402),
               'v9.6.0': get_links_usage(data960, link_960),
               'v9.6.1': get_links_usage(data961, link_961)}

# %%
all_plots = []
versions = ['v9.5.0', 'v9.4.2', 'v9.3.1', 'v9.4.0.2', 'v9.6.0', 'v9.6.1']

# %%
ab_test_skill_counts_relative_bar_fig = make_subplots(rows=1, cols=1, subplot_titles=(f'Link to by usage count (total link to by skill / total link to)',))

for v in versions:
    x = links_usage[v]['keys']
    y = links_usage[v]['total_links_percentage']
    z = list(zip(y, links_usage[v]['total_links'], links_usage[v]['success_links'], links_usage[v]['total_links_ratings'], links_usage[v]['success_links_ratings']))
    ab_test_skill_counts_relative_bar_fig.add_bar(name=v, x=x, y=y, customdata=z, hovertemplate = 'val: %{customdata[0]:.2f}; count: %{customdata[1]}; success count: %{customdata[2]}; rating: %{customdata[3]:.2f}; success rating: %{customdata[4]:.2f}')
ab_test_skill_counts_relative_bar_fig.update_layout(height=500, width=1300, showlegend=True)
ab_test_skill_counts_relative_bar_fig.update_layout(hovermode='x')
all_plots.append(ab_test_skill_counts_relative_bar_fig)

# %%
ab_test_skill_counts_relative_bar_fig = make_subplots(rows=1, cols=1, subplot_titles=(f'Success link to usage: (success link to by skill / total link to by skill)',))

for v in versions:
    x = links_usage[v]['keys']
    y = links_usage[v]['percentage_links']
    z = list(zip(y, links_usage[v]['total_links'], links_usage[v]['success_links'], links_usage[v]['total_links_ratings'], links_usage[v]['success_links_ratings']))
    ab_test_skill_counts_relative_bar_fig.add_bar(name=v, x=x, y=y, customdata=z, hovertemplate = 'val: %{customdata[0]:.2f} count: %{customdata[1]}; success count: %{customdata[2]}; rating: %{customdata[3]:.2f}; success rating: %{customdata[4]:.2f}')
ab_test_skill_counts_relative_bar_fig.update_layout(height=500, width=1300, showlegend=True)
ab_test_skill_counts_relative_bar_fig.update_layout(hovermode='x')
all_plots.append(ab_test_skill_counts_relative_bar_fig)

# %%
ab_test_skill_counts_relative_bar_fig = make_subplots(rows=1, cols=1, subplot_titles=(f'Link to by success rating',))

for v in versions:
    x = links_usage[v]['keys']
    y = links_usage[v]['success_links_ratings']
    z = list(zip(y, links_usage[v]['total_links'], links_usage[v]['success_links'], links_usage[v]['total_links_ratings'], links_usage[v]['success_links_ratings']))
    ab_test_skill_counts_relative_bar_fig.add_bar(name=v, x=x, y=y, customdata=z, hovertemplate = 'success rating: %{customdata[4]:.2f}; rating: %{customdata[3]:.2f}; count: %{customdata[1]}; success count: %{customdata[2]};')
ab_test_skill_counts_relative_bar_fig.update_layout(height=500, width=1300, showlegend=True)
ab_test_skill_counts_relative_bar_fig.update_layout(hovermode='x')
all_plots.append(ab_test_skill_counts_relative_bar_fig)

# %%
ab_test_skill_counts_relative_bar_fig = make_subplots(rows=1, cols=1, subplot_titles=(f'Link to by all rating',))

for v in versions:
    x = links_usage[v]['keys']
    y = links_usage[v]['total_links_ratings']
    z = list(zip(y, links_usage[v]['total_links'], links_usage[v]['success_links'], links_usage[v]['total_links_ratings'], links_usage[v]['success_links_ratings']))
    ab_test_skill_counts_relative_bar_fig.add_bar(name=v, x=x, y=y, customdata=z, hovertemplate = 'rating: %{customdata[3]:.2f}; success rating: %{customdata[4]:.2f}; count: %{customdata[1]}; success count: %{customdata[2]};')
ab_test_skill_counts_relative_bar_fig.update_layout(height=500, width=1300, showlegend=True)
ab_test_skill_counts_relative_bar_fig.update_layout(hovermode='x')
all_plots.append(ab_test_skill_counts_relative_bar_fig)

# %%
def append_plots(html_base, new_html):
    if html_base == None:
        return new_html
    plot_to_add = new_html.split('\n')[3:-2]
    html_base = '\n'.join(html_base.split('\n')[0:-2] + plot_to_add + html_base.split('\n')[-2:])
    return html_base
merged_html = ''
for p in all_plots:
    merged_html = append_plots(merged_html, p.to_html())
with open(f'./static/plot.html', 'w') as fout:
        fout.write(merged_html)
